# %% [markdown]
# # Task:3
# # Fraud Detection
# #

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #####  Data Reading

# %%
df=pd.read_csv(r"C:\Users\tejas\OneDrive\Desktop\Machine Leaening\archive (18)\creditcard.csv")

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df["Class"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ####  Duplicate Removal

# %%
df.duplicated().sum()
# Out:
# 1081

# %%
df=df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# sns.pairplot(df,hue="Amount",size=4)

# %%
df.hist(bins=50,figsize=(20,15))
plt.show()

# %%
correlation_figure, correlation_axis = plt.subplots(figsize = (15,20))
corr_mtrx = df.corr()
correlation_axis = sns.heatmap(corr_mtrx,cmap="PiYG",annot= True)

plt.xticks(rotation = 30, horizontalalignment = 'right', fontsize = 20)
plt.yticks(fontsize = 20)
plt.show()

# %% [markdown]
# # Machine Learning Algorithms

# %%
from sklearn.model_selection import train_test_split

# %%
x=df.drop("Class",axis=1)
y=df["Class"]
print(x.shape)
print(y.shape)
# Out:
# (283726, 30)
# (283726,)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=11)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (198608, 30)
# (85118, 30)
# (198608,)
# (85118,)

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

# %%
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=logreg.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 1.00
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84987
#            1       0.64      0.69      0.66       131
#
#     accuracy                           1.00     85118
#    macro avg       0.82      0.84      0.83     85118
# weighted avg       1.00      1.00      1.00     85118
#
# [[84937    50]
#  [   41    90]]

# %%
def display_results(y_test, y_pred):
    cm = confusion_matrix(y_test, y_pred)
    cm_matrix = pd.DataFrame(data=cm)
    print("Model Accuracy:",accuracy_score(y_test, y_pred))
    sns.heatmap(cm_matrix,cmap="PiYG", annot=True, fmt='d')

# %%
display_results(y_test, y_pred)
# Out:
# Model Accuracy: 0.9989308959327052

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(criterion='entropy')

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
pred=clf.predict(X_test)

# %%
ccuracy = accuracy_score(y_test, pred)
print(f'Accuracy: {accuracy:.2f}')
print(classification_report(y_test, pred))
print(confusion_matrix(y_test, pred))
# Out:
# Accuracy: 1.00
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     84987
#            1       0.75      0.73      0.74       131
#
#     accuracy                           1.00     85118
#    macro avg       0.87      0.87      0.87     85118
# weighted avg       1.00      1.00      1.00     85118
#
# [[84955    32]
#  [   35    96]]

# %%
def display_result(y_test, pred):
    cm1 = confusion_matrix(y_test,pred)
    cm_matrix1 = pd.DataFrame(data=cm1)
    print("Model Accuracy:",accuracy_score(y_test, pred))
    sns.heatmap(cm_matrix1,cmap="PiYG", annot=True, fmt='d')

# %%
display_result(y_test, pred)
# Out:
# Model Accuracy: 0.9992128574449588
